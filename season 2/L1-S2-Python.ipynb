# %%
import pandas as pd 
import numpy as np
import os
import glob
import matplotlib.pyplot as plt 
import seaborn as sns
import tensorflow

# %% [markdown]
# > Задание 1:
# > Напишите функцию (пусть она будет называться reverse_linked_list), которая разворачивает связный список. На вход она принимает головную ноду, а на выход отдаёт хвостовую ноду исходного списка, но только теперь если попробовать пройтись по ней, она будет новой головной. С функцией из примера выше,

# %%
class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next

def reverse_linked_list(head):
    previousNode = None
    cur = head
    nextNode = None
    
    while cur is not None:
        nextNode = cur.next
        cur.next = previousNode
        previousNode = cur
        cur = nextNode
        
    return previousNode

# %%
h, a, b, c, d = Node(1), Node(2), Node(3), Node("Внезапно"), Node(5)

h.next = a
a.next = b
b.next = c
c.next = d

print("Оригинальный LinkedList:")

print_linked_list(h)

print("\n")
print("Перевернутый LinkedList:")

newh = reverse_linked_list(h)

print_linked_list(newh)
# Out:
# Оригинальный LinkedList:
# [Node with value 1]
# [Node with value 2]
# [Node with value 3]
# [Node with value Внезапно]
# [Node with value 5]
#
#
# Перевернутый LinkedList:
# [Node with value 5]
# [Node with value Внезапно]
# [Node with value 3]
# [Node with value 2]
# [Node with value 1]

# %% [markdown]
# > Задание 2:
# > Сортировкой пузырьком это один из самых простейших алгоритмов сортировки, который можно придумать. В базовом виде он подразумеват вложенный цикл и реализуется как-то так
# >
# > l = [2, 4, 1, 1, 2, 0]
# >
# > for i in range(len(l)):
# >     for j in range(i, len(l)):
# >         if l[i] > l[j]:
# >             l[i], l[j] = l[j], l[i]
# >
# > print(l)
# > Вам предлагается написать функцию, которая будет на вход получать голову несортированного связного списка, а на выход возвращать голову отсортированного.
# >
# > Подсказка: так как в задании ничего не сказано про то, как должна вести себя функция, можете считать что можно просто менять значения, которые лежат в нодах, без замены их указателей. Или можете написать вспомогательную функцию, которая будет менять две ноды местами.

# %%
class Node(object):
    def __init__(self, value=None, next_node=None):
        self.value = value
        self.next = next_node

    def __str__(self):
        return f"[Node with value {self.value}]"


def print_linked_list(head):
    cur = head
    while cur is not None:
        print(cur)
        cur = cur.next
        
def size_linked_list(head):
    i = 0
    cur = head
    while cur is not None:
        i = i + 1
        cur = cur.next
    return i
        
def sort_linked_list(head):
    cur = head
    nextNode = head.next
    for i in range(size_linked_list(head)):
        while cur.next is not None:
            nextNode = cur.next
            if cur.value > nextNode.value:
                cur.value, nextNode.value = nextNode.value, cur.value
            
            cur = nextNode
        cur = head

# %%
h, a, b, c, d = Node(0), Node(-2), Node(68), Node(4), Node(1)

h.next = a
a.next = b
b.next = c
c.next = d

print("Оригинальный LinkedList:")

print_linked_list(h)

print("Отсортированный LinkedList:")

sort_linked_list(h)
print_linked_list(h)
# Out:
# Оригинальный LinkedList:
# [Node with value 0]
# [Node with value -2]
# [Node with value 68]
# [Node with value 4]
# [Node with value 1]
# Отсортированный LinkedList:
# [Node with value -2]
# [Node with value 0]
# [Node with value 1]
# [Node with value 4]
# [Node with value 68]

# %% [markdown]
# > Задача 3 Pandas
#
# > Выясните, сколько в среднем выходи полный счёт по пятницам на ланч у курящих мужчин (датасет tips)
#
# > Загрузите iris и посмотрите разбросы по всем числовым значениям для всех трёх классов цветов (датасет iris)
#
# > Создайте новый столбец с плотностью населения. Переименуйте названия первого и третьего столбца на русский язык
#
# > df = pd.DataFrame({
#      'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
#      'population': [17.04, 143.5, 9.5, 45.5],
#      'square': [2724902, 17125191, 207600, 603628]
#  })
#
# > df['density']

# %%
df = pd.read_csv("/kaggle/input/tips-and-iris/tips.csv")

df = df[(df['sex'] == 'Male') & (df['day'] == "Fri") & (df['smoker'] == "Yes") & (df['time'] == "Lunch")]
print("Среднее значение: " + str(df['total_bill'].mean()))
# Out:
# Среднее значение: 11.386666666666668

# %%
df = pd.read_csv("/kaggle/input/tips-and-iris/iris.csv")


print("Для Iris-setosa SepalLength min, max:", df[df.Name == "Iris-setosa"].SepalLength.min(), df[df.Name == "Iris-setosa"].SepalLength.max())
print("Для Iris-setosa SepalWidth min, max:", df[df.Name == "Iris-setosa"].SepalWidth.min(), df[df.Name == "Iris-setosa"].SepalWidth.max())
print("Для Iris-setosa PetalLength min, max:", df[df.Name == "Iris-setosa"].PetalLength.min(), df[df.Name == "Iris-setosa"].PetalLength.max())
print("Для Iris-setosa PetalWidth min, max:", df[df.Name == "Iris-setosa"].PetalWidth.min(), df[df.Name == "Iris-setosa"].PetalWidth.max())
print("\n")
print("Для Iris-versicolor SepalLength min, max:", df[df.Name == "Iris-versicolor"].SepalLength.min(), df[df.Name == "Iris-versicolor"].SepalLength.max())
print("Для Iris-versicolor SepalWidth min, max:", df[df.Name == "Iris-versicolor"].SepalWidth.min(), df[df.Name == "Iris-versicolor"].SepalWidth.max())
print("Для Iris-versicolor PetalLength min, max:", df[df.Name == "Iris-versicolor"].PetalLength.min(), df[df.Name == "Iris-versicolor"].PetalLength.max())
print("Для Iris-versicolor PetalWidth min, max:", df[df.Name == "Iris-versicolor"].PetalWidth.min(), df[df.Name == "Iris-versicolor"].PetalWidth.max())
print("\n")
print("Для Iris-virginica SepalLength min, max:", df[df.Name == "Iris-virginica"].SepalLength.min(), df[df.Name == "Iris-virginica"].SepalLength.max())
print("Для Iris-virginica SepalWidth min, max:", df[df.Name == "Iris-virginica"].SepalWidth.min(), df[df.Name == "Iris-virginica"].SepalWidth.max())
print("Для Iris-virginica PetalLength min, max:", df[df.Name == "Iris-virginica"].PetalLength.min(), df[df.Name == "Iris-virginica"].PetalLength.max())
print("Для Iris-virginica PetalWidth min, max:", df[df.Name == "Iris-virginica"].PetalWidth.min(), df[df.Name == "Iris-virginica"].PetalWidth.max())
# Out:
# Для Iris-setosa SepalLength min, max: 4.3 5.8
# Для Iris-setosa SepalWidth min, max: 2.3 4.4
# Для Iris-setosa PetalLength min, max: 1.0 1.9
# Для Iris-setosa PetalWidth min, max: 0.1 0.6
#
#
# Для Iris-versicolor SepalLength min, max: 4.9 7.0
# Для Iris-versicolor SepalWidth min, max: 2.0 3.4
# Для Iris-versicolor PetalLength min, max: 3.0 5.1
# Для Iris-versicolor PetalWidth min, max: 1.0 1.8
#
#
# Для Iris-virginica SepalLength min, max: 4.9 7.9
# Для Iris-virginica SepalWidth min, max: 2.2 3.8
# Для Iris-virginica PetalLength min, max: 4.5 6.9
# Для Iris-virginica PetalWidth min, max: 1.4 2.5

# %%
df = pd.DataFrame({
     'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
     'population': [17.04, 143.5, 9.5, 45.5],
     'square': [2724902, 17125191, 207600, 603628]
 })

df['Плотность'] = df['square'] / df['population']

df.rename(columns={"country": "Страна","square": "Площадь"}, inplace = 'True')

df.head()
# Out:
#        Страна  population   Площадь      Плотность
# 0  Kazakhstan       17.04   2724902  159912.089202
# 1      Russia      143.50  17125191  119339.310105
# 2     Belarus        9.50    207600   21852.631579
# 3     Ukraine       45.50    603628   13266.549451
